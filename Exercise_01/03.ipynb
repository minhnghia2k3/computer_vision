# %%
from PIL import Image
from helpers import *

# %%
dir = "/Users/minhnghia2k3/Documents/Computer vision/Exercise_01/assets"
img_path = dir + "/cat_meme.jpeg"

# %%
# Load image
img = load_image(img_path)
display(img)
# Out:
# Hello world!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
# Resize image
resize_path = dir + "/resized_cat.jpeg"
size = (400,400)
img.resize(size)
display(img)

img.save(resize_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
# Thumbnail size
thumbnail_path = dir + "/thumbnail_img.jpeg"
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)

img.save(thumbnail_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x50>
