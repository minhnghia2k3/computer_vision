# %%
from PIL import Image
from helpers import *

# %%
my_path = "/Users/minhnghia2k3/Documents/Computer vision/Exercise_01/assets/cat_meme.jpeg"

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
region = (150, 450, 300, 520)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=150x70>

# %%
paste_position = (400,300)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>
