# %%
# import Image from PIL
from PIL import Image

# %%
# current directory
dir = "/Users/minhnghia2k3/Documents/Computer vision/Exercise_01"

# %%
image_path = dir + "/assets/cat_meme.jpeg"
print(image_path)
# Out:
# /Users/minhnghia2k3/Documents/Computer vision/Exercise_01/assets/cat_meme.jpeg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
# Print image format
print("Imgae 01 format:", img01.format)
# Out:
# Imgae 01 format: JPEG

# %%
print("Image size:", img01.size)
# Out:
# Image size: (1000, 1000)

# %%
# Save and change image ext
new_img_01_JPG = dir + "/assets/new_01.JPG"
new_img_01_PNG = dir + "/assets/new_01.PNG"

img01.save(new_img_01_JPG)
img01.save(new_img_01_PNG)

# %%
img01.close()
