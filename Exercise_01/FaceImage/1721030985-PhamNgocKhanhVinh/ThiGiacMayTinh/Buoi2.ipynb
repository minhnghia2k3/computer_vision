# %%
# Shift + Enter: run code + add row
# Cài đặt
from PIL import Image

dir = 'C:/Users/Admin/Downloads/01'

# %%
image_path = dir +'/1.JPG'
print(image_path)
# Out:
# C:/Users/Admin/Downloads/01/1.JPG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
print("Dinh dang anh: ", img01.format)
Định dang ảnh:  JPEG
# Out:
#   Cell In[57], line 2
#     Định dang ảnh:  JPEG
#          ^
# SyntaxError: invalid syntax

# %%
print("Kích thước hình ảnh: ", img01.size)
Kích thước hình ảnh:  (450, 300)
# Out:
#   Cell In[20], line 2
#     Kích thước hình ảnh:  (450, 300)
#          ^
# SyntaxError: invalid syntax

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

img01.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 new_img_01_path = dir + '/new_01.JPG'
#       2 new_img_png_01_path = dir + '/new_01.PNG'
# ----> 3 img01.save(new_img_01_path)
#       4 img01.save(new_img_png_01_path)
#       6 img01.close()
#
# NameError: name 'img01' is not defined
