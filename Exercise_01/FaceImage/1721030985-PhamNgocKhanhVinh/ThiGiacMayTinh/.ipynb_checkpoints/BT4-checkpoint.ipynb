# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/Admin/Downloads/01/1.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
# Định vị khu vực cắt
region = (130, 98, 175, 175)

# %%
# Cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Dán
# Out:
# <PIL.Image.Image image mode=RGB size=45x77>

# %%
# Xác định vị trí cần dán
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
