# %%
from PIL import Image

# %%
dir = 'C:/Users/Admin/Downloads/img/1.jpg'

# %%
image_path = dir
print(image_path)
# Out:
# C:/Users/Admin/Downloads/img/1.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=405x720>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (405, 720)

# %%
new_img_01_path = dir + '/new_01.JPG'

# %%
img01.close()
