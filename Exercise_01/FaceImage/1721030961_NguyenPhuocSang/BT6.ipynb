# %%
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/Admin/Downloads/01/02.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x137>

# %%
# Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=300x137>

# %%
# Phân RGB thành 3 tầng màu khác nhau
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=300x137>
# <PIL.Image.Image image mode=L size=300x137>
# <PIL.Image.Image image mode=L size=300x137>

# %%
# Trộn ảnh
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x137>

# %%
merged_image =  Image.merge("RGB", (green_band,red_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x137>
