# %%
from PIL import Image
from helpers import *

# %%
my_path = "/Users/minhnghia2k3/Documents/Computer vision/Exercise_01/assets/cat_meme_02.jpeg"

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x532>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=480x532>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=480x532>
# <PIL.Image.Image image mode=L size=480x532>
# <PIL.Image.Image image mode=L size=480x532>

# %%
merged_img = Image.merge("RGB", (red_band,green_band,blue_band))
display(merged_img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x532>
