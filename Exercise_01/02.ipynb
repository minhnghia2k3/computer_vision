# %%
# Import
from PIL import Image
from helpers import *

# %%
# Working directory
dir = "/Users/minhnghia2k3/Documents/Computer vision/Exercise_01/assets"

# %%
# Read images
images = get_images_list(dir)

# %%
for img in images:
    print(img.size)
    display(img)
# Out:
# (480, 532)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x532>
# (512, 512)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=512x512>
# (314, 300)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=314x300>
# (993, 710)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=993x710>
# (1000, 1000)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>
