# %%
import matplotlib as mpl
from matplotlib import pyplot as plt
from PIL import Image

# %%
my_path = "/Users/minhnghia2k3/Documents/Computer vision/Exercise_01/assets/cat_meme_02.jpeg"
img = Image.open(my_path)
plt.imshow(img)

# %%
x = [1, 2, 10, 15]
y = [20, 24, 12, 50]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 10, 15]
y = [20, 24, 12, 50]
plt.plot(x, y, color="red")
plt.show()

# %%
x = [1, 2, 10, 15]
y = [20, 24, 12, 50]
plt.plot(x, y, color="red")
plt.title("Example Diagram")
plt.show()

# %%
x = [1, 2, 10, 15]
y = [20, 24, 12, 50]
plt.plot(x, y, color="red")
plt.title("Example Diagram without Axis")
plt.axis('off')
plt.show()

# %%
im = Image.open(my_path)
# left, bot, right, top
x = [250,2,3]
y = [100,200,300]
plt.imshow(im)
plt.plot(x,y,"go--")
plt.show()
